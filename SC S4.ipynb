# %%
import numpy as np 
 
def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not found a root")
  m = (a + b)/2

  if np.abs(f(m)) < tol:
    return m

  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)

  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m ,tol)
f = lambda x : x**2 - 3*x + 1

r1 = my_bisection(f, 0, 2, 0.1)
print("r1 = ", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 = ", r01)

print("f(r1) =", f(r1))
print("f(r01)=", f(r01))
# Out:
# r1 =  0.375
# r01 =  0.3828125
# f(r1) = 0.015625
# f(r01)= -0.00189208984375

# %%
#NEWTON-RAPHSON METHOD
f = lambda x : x**2 - 3*x + 1
f_prime = lambda x: 2*x
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))


#estimation of root of f
def my_newton(f, df, x0, tol):
  if abs(f(x0)) < tol :
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

print()
print("Estimation =", estimate)
# Out:
# Estimation = 2.6180335903799388

# %%
import numpy as np 
 
def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not found a root")
  m = (a + b)/2

  if np.abs(f(m)) < tol:
    return m

  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)

  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m ,tol)
f = lambda x : 2*x**2 + 12*x - 18

r1 = my_bisection(f, 0, 2, 0.1)
print("r1 = ", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 = ", r01)

print("f(r1) =", f(r1))
print("f(r01)=", f(r01))
# Out:
# r1 =  1.2421875
# r01 =  1.2421875
# f(r1) = -0.0076904296875
# f(r01)= -0.0076904296875

# %%
#NEWTON-RAPHSON METHOD
f = lambda x: 2*x**2 + 12*x - 18
f_prime = lambda x: 4*x + 12
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))


#estimation of root of f
def my_newton(f, df, x0, tol):
  if abs(f(x0)) < tol :
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

print()
estimate = my_newton(f, f_prime, 1, 1e-6)
print("Estimation =", estimate)
# Out:
# Estimation = 1.2426406871240696

# %%
import numpy as np 
 
def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not found a root")
  m = (a + b)/2

  if np.abs(f(m)) < tol:
    return m

  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)

  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m ,tol)
f = lambda x : 4*x**2 + 35*x - 12

r1 = my_bisection(f, 0, 2, 0.1)
print("r1 = ", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 = ", r01)

print("f(r1) =", f(r1))
print("f(r01)=", f(r01))
# Out:
# r1 =  0.328125
# r01 =  0.33056640625
# f(r1) = -0.0849609375
# f(r01)= 0.006920814514160156

# %%
#NEWTON-RAPHSON METHOD
f = lambda x: 4*x**2 + 35*x - 12
f_prime = lambda x: 8*x + 35
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))


#estimation of root of f
def my_newton(f, df, x0, tol):
  if abs(f(x0)) < tol :
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

print()
estimate = my_newton(f, f_prime, 1, 1e-6)
print("Estimation =", estimate)
# Out:
# Estimation = 0.3303825597476619

# %%
import numpy as np 
 
def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not found a root")
  m = (a + b)/2

  if np.abs(f(m)) < tol:
    return m

  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)

  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m ,tol)
f = lambda x : 2*x**4 + 3*x**3 - x**2 + 7*x - 1

r1 = my_bisection(f, 0, 2, 0.1)
print("r1 = ", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 = ", r01)

print("f(r1) =", f(r1))
print("f(r01)=", f(r01))
# Out:
# r1 =  0.15625
# r01 =  0.14453125
# f(r1) = 0.08197212219238281
# f(r01)= 0.0007596542127430439

# %%
#NEWTON-RAPHSON METHOD
f = lambda x: 2*x**4 + 3*x**3 - x**2 + 7*x - 1
f_prime = lambda x: 8*x**3 + 9*x**2-2*x + 7
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))


#estimation of root of f
def my_newton(f, df, x0, tol):
  if abs(f(x0)) < tol :
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

print()
estimate = my_newton(f, f_prime, 1, 1e-6)
print("Estimation =", estimate)
# Out:
# Estimation = 0.14442161750514304
