# %%
import numpy as np
x1 = 0
x2 = 0
x3 = 0
epsilon = 0.1
converged = False

x_old = np.array([x1, x2, x3])

print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1, 50):
    x1 = (18-5*x2+7*x3)/(13)
    x2 = (16-6*x3)/(1)
    x3 = (23-2*x1+5*x2)/(4)
    x = np.array([x1, x2, x3])
    # check if it is smaller than threshold
    dx = np.sqrt(np.dot(x-x_old, x-x_old))
    
    print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))
    if dx < epsilon:
        converged = True
        print('Converged!')
        break
        
    # assign the latest x value to the old value
    x_old = x

if not converged:
    print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 1.3846, 16.0000, 25.0577
# 2, 8.7234, -134.3462, -166.5444
# 3, -36.6215, 1015.2663, 1293.1436
# 4, 307.2057, -7742.8616, -9826.4299
# 5, -2311.7462, 58974.5793, 74879.8472
# 6, 17638.7719, -449263.0832, -570392.4899
# 7, -134339.5395, 3422370.9396, 4345139.1943
# 8, 1023395.2048, -26070819.1657, -33100215.8095
# 9, -7795953.6029, 198601310.8568, 252149621.1225
# 10, 59387754.7364, -1512897710.7350, -1920816010.0369
# 11, -452401807.5834, 11524896076.2215, 14632321004.8186
# 12, 3446289743.8940, -87793926012.9117, -111465552382.3366
# 13, -26253018199.5229, 668793314310.0195, 849118151993.0359
# 14, 199989268647.6272, -5094708911942.2148, -6468380774245.8320
# 15, -1523470835383.9810, 38810284645490.9922, 49274591224561.4844
# 16, 11605439641884.1074, -295647547347352.8750, -375362154005127.4375
# 17, -88407487792239.1875, 2252172924030780.5000, 2859419898934601.0000
# 18, 673467282491409.5000, -17156519393607590.0000, -21782382883255188.0000
# 19, -5130314093442180.0000, 130694297299531152.0000, 165933028671135040.0000
# 20, 39081516476945352.0000, -995598172026810240.0000, -1264038473271985408.0000
# 21, -297713727136142080.0000, 7584230839631912960.0000, 9629145413107961856.0000
# 22, 2267912591815090176.0000, -57774872478647771136.0000, -73352546894217265152.0000
# 23, -17276420451252459520.0000, 440115281365303558144.0000, 558782311932255666176.0000
# 24, 131607675130713210880.0000, -3352693871593533734912.0000, -4256671177057274167296.0000
# 25, -1002556067802557579264.0000, 25540027062343643955200.0000, 32426311861830833668096.0000
# 26, 7637234440084432879616.0000, -194557871170985010397184.0000, -247015956183773488349184.0000
# 27, -58178641340883789676544.0000, 1482095737102640997203968.0000, 1881708992048743191674880.0000
# 28, 443191096832922925137920.0000, -11290253952292460223791104.0000, -14334412988782038017376256.0000
# 29, -3376124704616304380739584.0000, 86006477932692219514322944.0000, 109196159768173433831030784.0000
# 30, 25718517593365614015021056.0000, -655176958609040568626446336.0000, -831830457057983453366059008.0000
# 31, -195917569720052439106715648.0000, 4990982742347901269952167936.0000, 6336687212794902824173436928.0000
# 32, 1492453598294216142003109888.0000, -38020123276769416945040621568.0000, -48271380895108874991694774272.0000
# 33, -11369157683224233524508753920.0000, 289628285370653232357982601216.0000, 367719935554928668204848906240.0000
# 34, 86607547848556497143651631104.0000, -2206319613329571868491605082112.0000, -2801203290586243005021494968320.0000
# 35, -659755766727372448725379055616.0000, 16807219743517458030128969809920.0000, 21338902562760507565755250769920.0000
# 36, 5025863017056635427526314819584.0000, -128033415376563036387332249878528.0000, -162554700729232098561229680803840.0000
# 37, -38285832940139202276087419633664.0000, 975328204375392591367378084823040.0000, 1238303171939310342599066129530880.0000
# 38, 291652398592169959798874577043456.0000, -7429819031635862343824772928897024.0000, -9433099988840913684299539357368320.0000
# 39, -2221738827977467562028106755604480.0000, 56598599933045484411640245357903872.0000, 71859119330295585260339093951217664.0000
# 40, 16924679665141666934806647110893568.0000, -431154715981773474668546416288202752.0000, -547405734809787716002417500548497408.0000
# 41, -128928197212280486544580089948930048.0000, 3284434408858726148440552413614571520.0000, 4170007109679548011833328893685661696.0000
# 42, 982144440266400240540096257121583104.0000, -25020042658077288070999973362113970176.0000, -31766125542729807774049797101542440960.0000
# 43, -7481743500670939180075556156198617088.0000, 190596753256378837199565816869964218368.0000, 241986813320809027895411256339667615744.0000
# 44, 56994148227982221311060629975214325760.0000, -1451920879924854091814603812123682275328.0000, -1843398174020058867094779566231566417920.0000
# 45, -434167909116626370732019809048594481152.0000, 11060389044120353202568677397389398507520.0000, 14042570259708756350849858621376160595968.0000
# 46, 3307388199796887035801551723019928338432.0000, -84255421558252542940802430186773662400512.0000, -106972971047714133980930554837611495555072.0000
# 47, -25194899195595091485582983363061174239232.0000, 641837826286284803885583329025668973330432.0000, 814894732455653625553171469070625635565568.0000
# 48, 191928768904473229108792560081244002451456.0000, -4889368394733921443834018993078685088612352.0000, -6207674877869638032490657744707642456014848.0000
# 49, -1462067859339835546393431343154673768988672.0000, 37246049267217828194943946468245854736089088.0000, 47288595513692211372971913933201510873694208.0000
# Not converge, increase the # of iterations

# %%
import numpy as np
x1 = 0
x2 = 0
x3 = 0
epsilon = 0.03
converged = False

x_old = np.array([x1, x2, x3])

print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1, 50):
    x1 = (6-3*x2-x3)/(-6)
    x2 = (8-5*x1-x3)/(7)
    x3 = (4-4*x1-6*x2)/(-12)
    x = np.array([x1, x2, x3])
    # check if it is smaller than threshold
    dx = np.sqrt(np.dot(x-x_old, x-x_old))
    
    print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))
    if dx < epsilon:
        converged = True
        print('Converged!')
        break
        
    # assign the latest x value to the old value
    x_old = x

if not converged:
    print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, -1.0000, 1.8571, 0.2619
# 2, -0.0278, 1.1253, 0.2200
# 3, -0.4007, 1.3976, 0.2319
# 4, -0.2625, 1.2973, 0.2278
# 5, -0.3134, 1.3342, 0.2293
# 6, -0.2947, 1.3206, 0.2287
# Converged!

# %%
import numpy as np
x1 = 0
x2 = 0
x3 = 0
epsilon = 0.001
converged = False

x_old = np.array([x1, x2, x3])

print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1, 50):
    x1 = (11+5*x2+7*x3)/(-3)
    x2 = (9-2*x1+8*x3)/(6)
    x3 = (6-4*x1-5*x2)/(3)
    x = np.array([x1, x2, x3])
    # check if it is smaller than threshold
    dx = np.sqrt(np.dot(x-x_old, x-x_old))
    
    print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))
    if dx < epsilon:
        converged = True
        print('Converged!')
        break
        
    # assign the latest x value to the old value
    x_old = x

if not converged:
    print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, -3.6667, 2.7222, 2.3519
# 2, -13.6914, 9.1996, 4.9225
# 3, -30.4851, 18.2250, 12.2718
# 4, -62.6759, 38.7543, 20.9773
# 5, -117.2042, 68.5378, 44.0427
# 6, -220.6625, 133.7777, 73.2538
# 7, -397.5552, 231.6902, 145.9233
# 8, -730.3046, 439.4992, 243.2408
# 9, -1303.7272, 760.3968, 472.9750
# 10, -2374.6029, 1423.6676, 795.3578
# 11, -4232.2809, 2472.7374, 1523.8122
# 12, -7680.4575, 4593.4021, 2586.9399
# 13, -13695.5298, 8015.9298, 4902.8235
# 14, -24803.4710, 14806.4216, 8395.9253
# 15, -44271.5285, 25953.2433, 15775.2992
# 16, -80068.1036, 47724.6001, 27218.4712
# 17, -143054.4331, 83977.6060, 50778.5675
# 18, -258449.6674, 153856.1458, 88174.6470
# 19, -462171.4191, 271624.8357, 163522.4994
# 20, -834264.2248, 496119.5742, 285488.3427
# 21, -1493009.0900, 878322.3203, 526810.2528
# 22, -2693098.1238, 1600114.5450, 923941.9234
# 23, -4822725.7295, 2839499.3076, 1697804.1266
# 24, -8694045.4748, 5161755.4937, 2989136.8102
# 25, -15577582.0467, 9178044.5958, 5473370.4026
# 26, -28067942.2656, 16653809.4586, 9667575.9231
# 27, -50314029.9183, 29661446.0370, 17649631.8295
# 28, -90618221.3305, 53738917.7162, 31259434.2470
# 29, -162503546.4366, 95847095.9749, 56926237.2907
# 30, -292573050.6365, 173426001.4332, 101054067.1267
# 31, -524836162.6843, 309684145.2304, 183641310.1951
# 32, -944636636.1725, 559733960.4842, 326625582.7563
# 33, -1695016297.5718, 1000506211.0323, 592511380.3752
# 34, -3050036909.5959, 1806694145.1988, 1055558972.7965
# 35, -5474127848.8565, 3232121248.1808, 1911968386.8407
# 36, -9848128319.9295, 5832000623.9308, 3410836722.0215
# 37, -17678620061.6014, 10440655651.3958, 6170400665.1422
# 38, -31798694307.9915, 18826765657.6868, 11020316316.5106
# 39, -57092014171.6694, 33724426480.7373, 19915308096.3304
# 40, -102676429696.3331, 60779220695.3849, 35603205104.8027
# 41, -184372846407.1810, 108928555610.2972, 64282869194.4126
# 42, -331540954141.1248, 196224143641.0917, 115014366121.6803
# 43, -595407093689.4067, 351821519393.5425, 207506925931.9714
# 44, -1070552026167.5043, 633526576633.2968, 371525073836.5110
# 45, -1922769466677.6868, 1136289920676.0769, 669876087778.7875
# 46, -3456860739280.9663, 2045455030133.5388, 1200055935487.3906
# 47, -6209222233030.1436, 3669815324994.7358, 2162604102384.2981
# 48, -11162435113891.5879, 6604283841144.4268, 3876107083283.4062
# 49, -20051389596238.9922, 11851939309792.3730, 6981953945333.3672
# Not converge, increase the # of iterations

# %%
import numpy as np
x1 = 0
x2 = 0
x3 = 0
epsilon = 0.02
converged = False

x_old = np.array([x1, x2, x3])

print('Iteration results')
print(' k,    x1,    x2,    x3 ')
for k in range(1, 50):
    x1 = (12-2*x2+4*x3)/(8)
    x2 = (1*x3)/(6)
    x3 = (8-5*x1-3*x2)/(-10)
    x = np.array([x1, x2, x3])
    # check if it is smaller than threshold
    dx = np.sqrt(np.dot(x-x_old, x-x_old))
    
    print("%d, %.4f, %.4f, %.4f"%(k, x1, x2, x3))
    if dx < epsilon:
        converged = True
        print('Converged!')
        break
        
    # assign the latest x value to the old value
    x_old = x

if not converged:
    print('Not converge, increase the # of iterations')
# Out:
# Iteration results
#  k,    x1,    x2,    x3
# 1, 1.5000, 0.0000, -0.0500
# 2, 1.4750, -0.0083, -0.0650
# 3, 1.4696, -0.0108, -0.0685
# Converged!
